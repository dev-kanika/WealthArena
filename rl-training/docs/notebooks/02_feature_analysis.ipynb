# %% [markdown]
# # 02 – Feature Analysis
#
# Analyze engineered features from the Gold layer, inspect correlations, and assess feature importance for PPO agents before training.
#
# **Objectives**
#
# - Load Gold-layer feature tables for a target asset class
# - Profile feature distributions, data quality, and correlation structure
# - Identify the most predictive signals using simple baseline models
# - Document noisy or redundant features to prune downstream

# %% [markdown]
# ## Setup

# %%
from __future__ import annotations

from pathlib import Path

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

pd.set_option("display.max_columns", 60)
pd.set_option("display.width", 140)
plt.style.use("seaborn-v0_8")
